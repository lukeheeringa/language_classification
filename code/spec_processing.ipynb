# %%
import librosa
import numpy as np
import pickle

from os import listdir

# %%
# https://towardsdatascience.com/understanding-audio-data-fourier-transform-fft-spectrogram-and-speech-recognition-a4072d228520
def spectrogram(samples, sample_rate, stride_ms = 10.0, 
                          window_ms = 20.0, max_freq = 8000, eps = 1e-14):

    stride_size = int(0.001 * sample_rate * stride_ms)
    window_size = int(0.001 * sample_rate * window_ms)

    # Extract strided windows
    truncate_size = (len(samples) - window_size) % stride_size
    samples = samples[:len(samples) - truncate_size]
    nshape = (window_size, (len(samples) - window_size) // stride_size + 1)
    nstrides = (samples.strides[0], samples.strides[0] * stride_size)
    windows = np.lib.stride_tricks.as_strided(samples, 
                                          shape = nshape, strides = nstrides)
    
    assert np.all(windows[:, 1] == samples[stride_size:(stride_size + window_size)])

    # Window weighting, squared Fast Fourier Transform (fft), scaling
    weighting = np.hanning(window_size)[:, None]
    
    fft = np.fft.rfft(windows * weighting, axis=0)
    fft = np.absolute(fft)
    fft = fft**2
    
    scale = np.sum(weighting**2) * sample_rate
    fft[1:-1, :] *= (2.0 / scale)
    fft[(0, -1), :] /= scale
    
    # Prepare fft frequency list
    freqs = float(sample_rate) / window_size * np.arange(fft.shape[0])
    
    # Compute spectrogram feature
    ind = np.where(freqs <= max_freq)[0][-1] + 1
    specgram = np.log(fft[:ind, :] + eps)
    return specgram

# %%
def audio_file_listing(source, lang_abbr):
    base_path = '../audio/' + source + '/' + lang_abbr + '/'
    return [f'{i:03}' + '___' + base_path + f for i, f in list(enumerate(listdir(base_path))) if '.mp3' in f]

# %%
def timeseries_file_listing(lang_abbr):
    base_path = '../data/timeseries/' + lang_abbr + '/'
    return [base_path + f for f in listdir(base_path) if '.pkl' in f]

# %%
def split_and_save(fname):
    # input is a string of format 'n___f' where n is the sample number and f is the file path
    n = fname.split('___')[0]
    n = np.int(n)
    path = '___'.join(fname.split('___')[1:])
    
    try:
        # load the full sample
        full, sr = librosa.load(path, sr=16000)
        # trim silence
        trim, start = librosa.effects.trim(full, sr)
        # calculate duration in seconds
        dur = len(trim) / sr
    except:
        return
    
    # splitting path from format '../audio/n_source/lang/sample.mp3'
    split = path.split('/')
    source = split[2].split('_')[0]
    lang = split[3]
    
    # set index
    i = 0
    
    # cut sample into 5 second clips and save
    for x in range(0, np.floor(dur / 5).astype('int') * 5, 5):
        try:
            sample = trim[x * sr : (x + 5) * sr]
            save_name = f'../data/timeseries/{lang}/{lang}{source}{n:03}{i:03}.pkl'
            with open(save_name, 'wb') as f:
                pickle.dump(sample, f)
        except:
            pass
        i += 1

# %%
def timeseries_to_spectrogram(path):
    # path comes in as ../data/timeseries/lang/file.pkl
    new_path = path.replace('timeseries', 'spectrogram')

    try:
        with open(path, 'rb') as f:
            reload = pickle.load(f)

        with open(new_path, 'wb') as f:
            pickle.dump(spectrogram(reload, 16000), f)
    except:
        pass

# %%
en1 = np.array(audio_file_listing('1_audiolingua', 'en'))

# %%
en1
# Out:
# array(['000___../audio/1_audiolingua/en/hello_my_name_is_samantha.mp3',
#        '001___../audio/1_audiolingua/en/the_great_gatsby_favourite_book.mp3',
#        '234___../audio/1_audiolingua/en/cars_in_the_us.mp3',
#        '235___../audio/1_audiolingua/en/kerry_tells_us_how_she_met_her_husband.mp3',
#        '236___../audio/1_audiolingua/en/about_melissa_1_melissa_etat_du_maine_usa.mp3',
#        '237___../audio/1_audiolingua/en/ok_darlene_-_heroes.mp3',
#        '238___../audio/1_audiolingua/en/millenials_and_social_media.mp3',
#        '239___../audio/1_audiolingua/en/my_name_s_holly.mp3',
#        '240___../audio/1_audiolingua/en/richard_holidays_south_africa_converted.mp3',
#        '241___../audio/1_audiolingua/en/mary_-_relationship_france_uk.mp3',
#        '242___../audio/1_audiolingua/en/gwen_list.mp3',
#        '243___../audio/1_audiolingua/en/amy_tries_to_convince_her_brother_to_take_french_next_year.mp3',
#        '244___../audio/1_audiolingua/en/time_capsule.mp3',
#        '245___../audio/1_audiolingua/en/fiona_morning_routine.mp3',
#        '246___../audio/1_audiolingua/en/mary_-_i_m_not_going_back_to_the_uk.mp3',
#        '247___../audio/1_audiolingua/en/comparison_size_france_us.mp3',
#        '248___../audio/1_audiolingua/en/vernon_-_policeman.mp3',
#        '249___../audio/1_audiolingua/en/little_reindeer_lily.mp3',
#        '250___../audio/1_audiolingua/en/holi_festival.mp3',
#        '251___../audio/1_audiolingua/en/milly_and_juliet_school.mp3',
#        '252___../audio/1_audiolingua/en/the_empire_state_building_jane.mp3',
#        '253___../audio/1_audiolingua/en/adiya_tnt.mp3',
#        '254___../audio/1_audiolingua/en/rachel_houses.mp3',
#        '255___../audio/1_audiolingua/en/house.mp3',
#        '256___../audio/1_audiolingua/en/jordan_s_gap_year_v2.mp3',
#        '257___../audio/1_audiolingua/en/peyton_-_clubs_and_activities.mp3',
#        '258___../audio/1_audiolingua/en/3-life_in_paris_is_different_from_life_in_india.mp3',
#        '259___../audio/1_audiolingua/en/hello_my_name_is_mia_saf_animals.mp3',
#        '260___../audio/1_audiolingua/en/keely_food.mp3',
#        '261___../audio/1_audiolingua/en/renee_-_multicultural_chicago.mp3',
#        '262___../audio/1_audiolingua/en/indian_national_anthem.mp3',
#        '263___../audio/1_audiolingua/en/food-2.mp3',
#        '264___../audio/1_audiolingua/en/today_it_s_raining.mp3',
#        '265___../audio/1_audiolingua/en/facebook_olivia.mp3',
#        '266___../audio/1_audiolingua/en/how_does_he_get_informed.mp3',
#        '267___../audio/1_audiolingua/en/i_can_sing_a_rainbow.mp3',
#        '268___../audio/1_audiolingua/en/xmas_spirit.mp3',
#        '269___../audio/1_audiolingua/en/answer_phone_message_2_jane.mp3',
#        '270___../audio/1_audiolingua/en/peyton_-_the_best_experience_of_my_life.mp3',
#        '271___../audio/1_audiolingua/en/justin-_sailing_in_a_hurricane.mp3',
#        '272___../audio/1_audiolingua/en/jersey_devil_story.mp3',
#        '273___../audio/1_audiolingua/en/about_the_country.mp3',
#        '274___../audio/1_audiolingua/en/kamala_harris_bio.mp3',
#        '275___../audio/1_audiolingua/en/rachel_s_show_and_tell.mp3',
#        '276___../audio/1_audiolingua/en/renee_-_my_top_10_cities.mp3',
#        '277___../audio/1_audiolingua/en/jane_survivor_audition_tape_-_ailsa.mp3',
#        '278___../audio/1_audiolingua/en/my_new_year_s_resolutions_video_rachel_london.mp3',
#        '279___../audio/1_audiolingua/en/13-_bollywood.mp3',
#        '280___../audio/1_audiolingua/en/katie_gb_meansoftransport.mp3',
#        '281___../audio/1_audiolingua/en/terence_-_the_who.mp3',
#        '282___../audio/1_audiolingua/en/christmas_list_kids.mp3',
#        '283___../audio/1_audiolingua/en/ulka_-_india.mp3',
#        '284___../audio/1_audiolingua/en/grow_up.mp3',
#        '285___../audio/1_audiolingua/en/keely_things_i_like_to_do.mp3',
#        '286___../audio/1_audiolingua/en/ok_darlene_-_superheroes.mp3',
#        '287___../audio/1_audiolingua/en/superman_-_ailsa.mp3',
#        '288___../audio/1_audiolingua/en/pledge_of_allegiance.mp3',
#        '289___../audio/1_audiolingua/en/la_presse.mp3',
#        '290___../audio/1_audiolingua/en/justin-_two_dogs.mp3',
#        '291___../audio/1_audiolingua/en/foods.mp3',
#        '292___../audio/1_audiolingua/en/universites.mp3',
#        '293___../audio/1_audiolingua/en/my_high_school_in_nyc.mp3',
#        '294___../audio/1_audiolingua/en/family_education_and_school_education_about_food.mp3',
#        '295___../audio/1_audiolingua/en/peyton_-_football_source_of_revenue.mp3',
#        '296___../audio/1_audiolingua/en/lazy_jane.mp3',
#        '297___../audio/1_audiolingua/en/ghandi_angelin_india.mp3',
#        '298___../audio/1_audiolingua/en/rebecca_valentine_s_day.mp3',
#        '299___../audio/1_audiolingua/en/dentist_sophia_goodwin.mp3',
#        '300___../audio/1_audiolingua/en/adele_tnt-2.mp3',
#        '301___../audio/1_audiolingua/en/sophie_christmasja.mp3',
#        '302___../audio/1_audiolingua/en/peyton_-_being_a_student_can_be_stressful_2.mp3',
#        '303___../audio/1_audiolingua/en/breanne_l.mp3',
#        '304___../audio/1_audiolingua/en/the_color_song_wo_speech_intro.mp3',
#        '305___../audio/1_audiolingua/en/weather_forecast_-_jack_wilson_charlotte_usa.mp3',
#        '306___../audio/1_audiolingua/en/vernon_-_post_brexit_negotiations.mp3',
#        '307___../audio/1_audiolingua/en/peyton_-_millenials.mp3',
#        '308___../audio/1_audiolingua/en/answer_phone_message_1_claire.mp3',
#        '309___../audio/1_audiolingua/en/helen.mp3',
#        '310___../audio/1_audiolingua/en/i_am_from_chicago.mp3',
#        '311___../audio/1_audiolingua/en/liz_recycling_3.mp3',
#        '312___../audio/1_audiolingua/en/1-mumbai_1.mp3',
#        '313___../audio/1_audiolingua/en/tanya_-_amir_s_story.mp3',
#        '314___../audio/1_audiolingua/en/justin-_social_media.mp3',
#        '315___../audio/1_audiolingua/en/routine-2.mp3',
#        '316___../audio/1_audiolingua/en/procastination_leo_glassman.mp3',
#        '317___../audio/1_audiolingua/en/nicole_christmasja.mp3',
#        '318___../audio/1_audiolingua/en/ok_felix_-_commonwealth.mp3',
#        '319___../audio/1_audiolingua/en/rebecca_facebook.mp3',
#        '320___../audio/1_audiolingua/en/leslie_my_brother.mp3',
#        '321___../audio/1_audiolingua/en/bh.mp3',
#        '322___../audio/1_audiolingua/en/the_canadian.mp3',
#        '323___../audio/1_audiolingua/en/rachel_s_favourite_book.mp3',
#        '324___../audio/1_audiolingua/en/in_search_of_cinderella.mp3',
#        '325___../audio/1_audiolingua/en/chores_in_my_family.mp3',
#        '326___../audio/1_audiolingua/en/elias_and_john_hobbies_and_glasgow.mp3',
#        '327___../audio/1_audiolingua/en/hello_my_name_is_lauren.mp3',
#        '328___../audio/1_audiolingua/en/vegetarianism_renee.mp3',
#        '329___../audio/1_audiolingua/en/steven_-_i_work_at_the_hpotter_studios.mp3',
#        '330___../audio/1_audiolingua/en/shambles_1.mp3',
#        '331___../audio/1_audiolingua/en/shambles_3.mp3',
#        '332___../audio/1_audiolingua/en/kerry_her_worst_memory.mp3',
#        '333___../audio/1_audiolingua/en/the_planet_of_mars.mp3',
#        '334___../audio/1_audiolingua/en/pancake_day_chant.mp3',
#        '335___../audio/1_audiolingua/en/welcome_to_the_australian_zoo.mp3',
#        '336___../audio/1_audiolingua/en/lottery.mp3',
#        '337___../audio/1_audiolingua/en/a_present.mp3',
#        '338___../audio/1_audiolingua/en/anna_the_giver_california_us.mp3',
#        '339___../audio/1_audiolingua/en/vernon_-_the_queen_buckingham.mp3',
#        '340___../audio/1_audiolingua/en/peppermint_stick.mp3',
#        '341___../audio/1_audiolingua/en/i_love_my_family.mp3',
#        '342___../audio/1_audiolingua/en/liz_recycling_1.mp3',
#        '343___../audio/1_audiolingua/en/hospital.mp3',
#        '344___../audio/1_audiolingua/en/anna_gun_possession_california_us.mp3',
#        '345___../audio/1_audiolingua/en/aquaman_and_flash_-jessica_canada_.mp3',
#        '346___../audio/1_audiolingua/en/shambles_2.mp3',
#        '347___../audio/1_audiolingua/en/is_it_possible_to_eat_healthy_food.mp3',
#        '348___../audio/1_audiolingua/en/liz_recycling_5.mp3',
#        '349___../audio/1_audiolingua/en/mary_-_pbs_raised_by_brexit.mp3',
#        '350___../audio/1_audiolingua/en/nicole_new_years_eveja.mp3',
#        '351___../audio/1_audiolingua/en/eh_dchs_recording.mp3',
#        '352___../audio/1_audiolingua/en/rachel_s_family_physical_description_.mp3',
#        '353___../audio/1_audiolingua/en/melissa_s_lockdown_experience___.mp3',
#        '354___../audio/1_audiolingua/en/breakfast_in_america.mp3',
#        '355___../audio/1_audiolingua/en/rache_ls_favourite_recipe.mp3',
#        '356___../audio/1_audiolingua/en/14-_festival_of_holi.mp3',
#        '357___../audio/1_audiolingua/en/rosie_s_walk.mp3',
#        '358___../audio/1_audiolingua/en/animals.mp3',
#        '359___../audio/1_audiolingua/en/8_traditionnal_christmas_food_in_nz.mp3',
#        '360___../audio/1_audiolingua/en/my_school_uniform-2.mp3',
#        '361___../audio/1_audiolingua/en/helena_gb_sport.mp3',
#        '362___../audio/1_audiolingua/en/painting_1.mp3',
#        '363___../audio/1_audiolingua/en/the_woolworth_building_jane.mp3',
#        '364___../audio/1_audiolingua/en/steven_-_harry_potter_castle_model.mp3',
#        '365___../audio/1_audiolingua/en/schools-2.mp3',
#        '366___../audio/1_audiolingua/en/3-_the_day_of_thanksgiving.mp3',
#        '367___../audio/1_audiolingua/en/liz_recycling_4.mp3',
#        '368___../audio/1_audiolingua/en/ok_chara_headgirl.mp3',
#        '369___../audio/1_audiolingua/en/bio_of_joe_biden.mp3',
#        '370___../audio/1_audiolingua/en/vernon_-_nobody_understands_brexit.mp3',
#        '371___../audio/1_audiolingua/en/lily_school_tour.mp3',
#        '372___../audio/1_audiolingua/en/hanna_pancakes.mp3',
#        '373___../audio/1_audiolingua/en/february_vacation.mp3',
#        '374___../audio/1_audiolingua/en/peyton_-_my_tuition_fees.mp3',
#        '375___../audio/1_audiolingua/en/angelin_-_india_introduce_myself.mp3',
#        '376___../audio/1_audiolingua/en/peyton_-_the_university_of_oklahoma.mp3',
#        '377___../audio/1_audiolingua/en/painting_3.mp3',
#        '378___../audio/1_audiolingua/en/2-_family_tradition.mp3',
#        '379___../audio/1_audiolingua/en/11-_my_favourite_typical_dish.mp3',
#        '380___../audio/1_audiolingua/en/future.mp3',
#        '381___../audio/1_audiolingua/en/perfect_outfit.mp3',
#        '382___../audio/1_audiolingua/en/elliot_and_roderick_music_and_birds.mp3',
#        '383___../audio/1_audiolingua/en/rachel_last_week_end.mp3',
#        '384___../audio/1_audiolingua/en/vernon_-_i_got_badly_injured.mp3',
#        '385___../audio/1_audiolingua/en/renee_-_my_favourite_dish.mp3',
#        '386___../audio/1_audiolingua/en/brexit_and_northern_ireland_issue.mp3',
#        '387___../audio/1_audiolingua/en/anna_gb_sport.mp3',
#        '388___../audio/1_audiolingua/en/peyton_-_being_a_student_can_be_stressful.mp3',
#        '389___../audio/1_audiolingua/en/marriages_angelin_india.mp3',
#        '390___../audio/1_audiolingua/en/painting_2.mp3',
#        '391___../audio/1_audiolingua/en/ok_felix_-_gun_violence.mp3',
#        '392___../audio/1_audiolingua/en/adiya_tnt-2.mp3',
#        '393___../audio/1_audiolingua/en/travel.mp3',
#        '394___../audio/1_audiolingua/en/kerry_tells_us_about_her_daily_routine.mp3',
#        '395___../audio/1_audiolingua/en/why-i-like-graffiti.mp3',
#        '396___../audio/1_audiolingua/en/grinch.mp3',
#        '397___../audio/1_audiolingua/en/are_you_black_or_white.mp3',
#        '398___../audio/1_audiolingua/en/utah_in_quarentine_-_copie.mp3',
#        '399___../audio/1_audiolingua/en/orla_things_to_do_in_glasgow.mp3',
#        '400___../audio/1_audiolingua/en/peyton_-_college_worth_the_cost.mp3',
#        '401___../audio/1_audiolingua/en/amy_xmas1_ja.mp3'], dtype='<U111')

# %%
zh1 = np.array(audio_file_listing('1_audiolingua', 'zh'))

# %%
v_split_and_save = np.vectorize(split_and_save)

# %%
# v_split_and_save(en1)

# %%
# v_split_and_save(zh1)

# %%
en1_t = np.array(timeseries_file_listing('en'))
zh1_t = np.array(timeseries_file_listing('zh'))

# %%
v_timeseries_to_spectrogram = np.vectorize(timeseries_to_spectrogram)

# %%
v_timeseries_to_spectrogram(en1_t)
# Out:
# array([None, None, None, ..., None, None, None], dtype=object)

# %%
# %%time
v_timeseries_to_spectrogram(zh1_t)
# Out:
# CPU times: user 10.8 s, sys: 3.28 s, total: 14.1 s
# Wall time: 31.7 s
# array([None, None, None, ..., None, None, None], dtype=object)
